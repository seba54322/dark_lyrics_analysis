# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Aries-(2010---wc)" data-toc-modified-id="Aries-(2010---wc)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Aries (2010 - wc)</a></span></li><li><span><a href="#Just-a-reminder" data-toc-modified-id="Just-a-reminder-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Just a reminder</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#leer" data-toc-modified-id="leer-2.0.0.0.1"><span class="toc-item-num">2.0.0.0.1&nbsp;&nbsp;</span>leer</a></span></li><li><span><a href="#guardar" data-toc-modified-id="guardar-2.0.0.0.2"><span class="toc-item-num">2.0.0.0.2&nbsp;&nbsp;</span>guardar</a></span></li><li><span><a href="#despliegue-de-información" data-toc-modified-id="despliegue-de-información-2.0.0.0.3"><span class="toc-item-num">2.0.0.0.3&nbsp;&nbsp;</span>despliegue de información</a></span></li><li><span><a href="#nombrar-columnas" data-toc-modified-id="nombrar-columnas-2.0.0.0.4"><span class="toc-item-num">2.0.0.0.4&nbsp;&nbsp;</span>nombrar columnas</a></span></li><li><span><a href="#value-counts" data-toc-modified-id="value-counts-2.0.0.0.5"><span class="toc-item-num">2.0.0.0.5&nbsp;&nbsp;</span>value counts</a></span></li><li><span><a href="#sort-by" data-toc-modified-id="sort-by-2.0.0.0.6"><span class="toc-item-num">2.0.0.0.6&nbsp;&nbsp;</span>sort by</a></span></li><li><span><a href="#randomize" data-toc-modified-id="randomize-2.0.0.0.7"><span class="toc-item-num">2.0.0.0.7&nbsp;&nbsp;</span>randomize</a></span></li></ul></li></ul></li></ul></li></ul></li><li><span><a href="#0---Opening-df_en" data-toc-modified-id="0---Opening-df_en-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>0 - Opening df_en</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Stopwords" data-toc-modified-id="Stopwords-3.0.0.0.1"><span class="toc-item-num">3.0.0.0.1&nbsp;&nbsp;</span>Stopwords</a></span></li></ul></li></ul></li></ul></li></ul></li><li><span><a href="#1---Todas-las-letras,-inglés,-custom-stopwords,-top-200-df_en.lyric" data-toc-modified-id="1---Todas-las-letras,-inglés,-custom-stopwords,-top-200-df_en.lyric-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>1 - Todas las letras, inglés, custom stopwords, top 200 df_en.lyric</a></span></li><li><span><a href="#2---Todas-las-letras,-inglés,-custom-stopwords,-top-50-df_en.lyric" data-toc-modified-id="2---Todas-las-letras,-inglés,-custom-stopwords,-top-50-df_en.lyric-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>2 - Todas las letras, inglés, custom stopwords, top 50 df_en.lyric</a></span></li><li><span><a href="#Word-Cloud-by-genre" data-toc-modified-id="Word-Cloud-by-genre-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Word Cloud by genre</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Estandarizar-nombres-de-bandas" data-toc-modified-id="Estandarizar-nombres-de-bandas-6.0.0.0.1"><span class="toc-item-num">6.0.0.0.1&nbsp;&nbsp;</span>Estandarizar nombres de bandas</a></span></li><li><span><a href="#Abrir-dataset-banda-género-país" data-toc-modified-id="Abrir-dataset-banda-género-país-6.0.0.0.2"><span class="toc-item-num">6.0.0.0.2&nbsp;&nbsp;</span>Abrir dataset banda género país</a></span></li><li><span><a href="#Merge-de-letras,-géneros-y-países" data-toc-modified-id="Merge-de-letras,-géneros-y-países-6.0.0.0.3"><span class="toc-item-num">6.0.0.0.3&nbsp;&nbsp;</span>Merge de letras, géneros y países</a></span></li><li><span><a href="#Filtrado-de-datasets-por-género-(3-4)" data-toc-modified-id="Filtrado-de-datasets-por-género-(3-4)-6.0.0.0.4"><span class="toc-item-num">6.0.0.0.4&nbsp;&nbsp;</span>Filtrado de datasets por género (3-4)</a></span></li><li><span><a href="#Inglés-Power-Metal-len" data-toc-modified-id="Inglés-Power-Metal-len-6.0.0.0.5"><span class="toc-item-num">6.0.0.0.5&nbsp;&nbsp;</span>Inglés Power Metal len</a></span></li><li><span><a href="#Inglés-Power-Metal-groupby-país" data-toc-modified-id="Inglés-Power-Metal-groupby-país-6.0.0.0.6"><span class="toc-item-num">6.0.0.0.6&nbsp;&nbsp;</span>Inglés Power Metal groupby país</a></span></li><li><span><a href="#Inglés-Power-Metal-groupby-banda" data-toc-modified-id="Inglés-Power-Metal-groupby-banda-6.0.0.0.7"><span class="toc-item-num">6.0.0.0.7&nbsp;&nbsp;</span>Inglés Power Metal groupby banda</a></span></li><li><span><a href="#Inglés-Black-Metal-len" data-toc-modified-id="Inglés-Black-Metal-len-6.0.0.0.8"><span class="toc-item-num">6.0.0.0.8&nbsp;&nbsp;</span>Inglés Black Metal len</a></span></li><li><span><a href="#Inglés-Black-Metal-groupby-país" data-toc-modified-id="Inglés-Black-Metal-groupby-país-6.0.0.0.9"><span class="toc-item-num">6.0.0.0.9&nbsp;&nbsp;</span>Inglés Black Metal groupby país</a></span></li><li><span><a href="#Inglés-Black-Metal-groupby-banda" data-toc-modified-id="Inglés-Black-Metal-groupby-banda-6.0.0.0.10"><span class="toc-item-num">6.0.0.0.10&nbsp;&nbsp;</span>Inglés Black Metal groupby banda</a></span></li><li><span><a href="#Inglés-Black-Metal-Favoritos" data-toc-modified-id="Inglés-Black-Metal-Favoritos-6.0.0.0.11"><span class="toc-item-num">6.0.0.0.11&nbsp;&nbsp;</span>Inglés Black Metal Favoritos</a></span></li><li><span><a href="#Inglés-Black-Metal-Favoritos-len" data-toc-modified-id="Inglés-Black-Metal-Favoritos-len-6.0.0.0.12"><span class="toc-item-num">6.0.0.0.12&nbsp;&nbsp;</span>Inglés Black Metal Favoritos len</a></span></li><li><span><a href="#Inglés-Black-Metal-Favoritos-groupby-país" data-toc-modified-id="Inglés-Black-Metal-Favoritos-groupby-país-6.0.0.0.13"><span class="toc-item-num">6.0.0.0.13&nbsp;&nbsp;</span>Inglés Black Metal Favoritos groupby país</a></span></li><li><span><a href="#Inglés-Black-Metal-Favoritos-groupby-banda" data-toc-modified-id="Inglés-Black-Metal-Favoritos-groupby-banda-6.0.0.0.14"><span class="toc-item-num">6.0.0.0.14&nbsp;&nbsp;</span>Inglés Black Metal Favoritos groupby banda</a></span></li><li><span><a href="#Filtrado-de-datasets-por-género-+-país-(5---14)" data-toc-modified-id="Filtrado-de-datasets-por-género-+-país-(5---14)-6.0.0.0.15"><span class="toc-item-num">6.0.0.0.15&nbsp;&nbsp;</span>Filtrado de datasets por género + país (5 - 14)</a></span></li></ul></li></ul></li></ul></li></ul></li><li><span><a href="#3---Inglés,-Power-(top-50)-df_en_power.lyric" data-toc-modified-id="3---Inglés,-Power-(top-50)-df_en_power.lyric-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>3 - Inglés, Power (top 50) df_en_power.lyric</a></span></li><li><span><a href="#4---Inglés,-Black-(top-50)-df_en_black.lyric" data-toc-modified-id="4---Inglés,-Black-(top-50)-df_en_black.lyric-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>4 - Inglés, Black (top 50) df_en_black.lyric</a></span></li><li><span><a href="#5---Inglés,-Power,-Alemania-(top-50)-df_en_power_germany.lyric" data-toc-modified-id="5---Inglés,-Power,-Alemania-(top-50)-df_en_power_germany.lyric-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>5 - Inglés, Power, Alemania (top 50) df_en_power_germany.lyric</a></span></li><li><span><a href="#6---Inglés,-Power,-Estados-Unidos-(top-50)-df_en_power_usa.lyric" data-toc-modified-id="6---Inglés,-Power,-Estados-Unidos-(top-50)-df_en_power_usa.lyric-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>6 - Inglés, Power, Estados Unidos (top 50) df_en_power_usa.lyric</a></span></li><li><span><a href="#7---Inglés,-Power,-Suecia-(top-50)-df_en_power_sweden.lyric" data-toc-modified-id="7---Inglés,-Power,-Suecia-(top-50)-df_en_power_sweden.lyric-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>7 - Inglés, Power, Suecia (top 50) df_en_power_sweden.lyric</a></span></li><li><span><a href="#8---Inglés,-Power,-Finlandia-(top-50)-df_en_power_finland.lyric" data-toc-modified-id="8---Inglés,-Power,-Finlandia-(top-50)-df_en_power_finland.lyric-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>8 - Inglés, Power, Finlandia (top 50) df_en_power_finland.lyric</a></span></li><li><span><a href="#9---Inglés,-Power,-Italia-(top-50)-df_en_power_italy.lyric" data-toc-modified-id="9---Inglés,-Power,-Italia-(top-50)-df_en_power_italy.lyric-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>9 - Inglés, Power, Italia (top 50) df_en_power_italy.lyric</a></span></li><li><span><a href="#10---Inglés,-Black,-Noruega-(top-50)-df_en_black_norway.lyric" data-toc-modified-id="10---Inglés,-Black,-Noruega-(top-50)-df_en_black_norway.lyric-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>10 - Inglés, Black, Noruega (top 50) df_en_black_norway.lyric</a></span></li><li><span><a href="#11---Inglés,-Black,-Suecia-(top-50)-df_en_black_sweden.lyric" data-toc-modified-id="11---Inglés,-Black,-Suecia-(top-50)-df_en_black_sweden.lyric-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>11 - Inglés, Black, Suecia (top 50) df_en_black_sweden.lyric</a></span></li><li><span><a href="#12---Inglés,-Black,-Estados-Unidos-(top-50)-df_en_black_usa.lyric" data-toc-modified-id="12---Inglés,-Black,-Estados-Unidos-(top-50)-df_en_black_usa.lyric-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>12 - Inglés, Black, Estados Unidos (top 50) df_en_black_usa.lyric</a></span></li><li><span><a href="#13---Inglés,-Black,-Finlandia-(top-50)-df_en_black_finland.lyric" data-toc-modified-id="13---Inglés,-Black,-Finlandia-(top-50)-df_en_black_finland.lyric-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>13 - Inglés, Black, Finlandia (top 50) df_en_black_finland.lyric</a></span></li><li><span><a href="#14---Inglés,-Black,-Alemania-(top-50)-df_en_black_germany.lyric" data-toc-modified-id="14---Inglés,-Black,-Alemania-(top-50)-df_en_black_germany.lyric-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>14 - Inglés, Black, Alemania (top 50) df_en_black_germany.lyric</a></span></li><li><span><a href="#15---Inglés,-Black,-Favoritos-(top-50)-df_en_black_favoritos.lyric" data-toc-modified-id="15---Inglés,-Black,-Favoritos-(top-50)-df_en_black_favoritos.lyric-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>15 - Inglés, Black, Favoritos (top 50) df_en_black_favoritos.lyric</a></span></li></ul></div>

# %% [markdown]
# # Aries (2010 - wc)

# %%
# -*- coding: utf-8 -*-
#!/usr/bin/python
# %matplotlib inline
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords 
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Just a reminder

# %% [markdown]
# ##### leer
# df = pd.read_csv('documento.csv')
# df = pd.read_pickle('documento.pkl')
# ##### guardar
# df = df.to_csv('documento.csv')
# ##### despliegue de información
# pd.set_option('display.width', 900) <br>
# pd.set_option('display.max_colwidth', 1)<br>
# pd.set_option('display.max_rows', 900)<br>
# pd.set_option('display.max_columns', None)<br>
# ##### nombrar columnas
# df.columns = ['columna_1', 'columna_2','columna_n']
# ##### value counts
# df['columna'].value_counts()
# ##### sort by
# df.sort_values(by=['columna'])
# ##### randomize
# df.sample(frac=1)

# %% [markdown]
# # 0 - Opening df_en

# %%
df_en = pd.read_csv('./from_scratch/002_df_ingles_puro.csv')
df_en
# Out:
#         Unnamed: 0  Unnamed: 0.1        band_name  \
# 0                0             0   CHRONIX REVOLT
# 1                1             1  DEFEATED SANITY
# 2                2             2  DEFEATED SANITY
# 3                3             3  DEFEATED SANITY
# 4                4             4  DEFEATED SANITY
# ...            ...           ...              ...
# 175212      198182        198182        CARNIVORE
# 175213      198183        198183        CARNIVORE
# 175214      198184        198184        CARNIVORE
# 175215      198185        198185        CARNIVORE
# 175216      198186        198186        CARNIVORE
#
#                               album_name album_year  \
# 0       The Impending Fall Of The System       2014
# 1                 Chapters Of Repugnance       2010
# 2                 Chapters Of Repugnance       2010
# 3                 Chapters Of Repugnance       2010
# 4                 Chapters Of Repugnance       2010
# ...

# %% [markdown]
# ##### Stopwords

# %%
stopwords = ["now", "death", "life", "will"] + list(STOPWORDS)
stopwords = set(stopwords)

# %% [markdown]
# # 1 - Todas las letras, inglés, custom stopwords, top 200 df_en.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en.lyric
# Ingresa descripción de la visualización
registro = 'Todas las letras, inglés, custom stopwords, top 200'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=200,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:02:05.67
# /n
# Todas las letras, inglés, custom stopwords, top 200

# %% [markdown]
# # 2 - Todas las letras, inglés, custom stopwords, top 50 df_en.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en.lyric
# Ingresa descripción de la visualización
registro = 'Todas las letras, inglés, custom stopwords, top 50'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:01:54.59
# /n
# Todas las letras, inglés, custom stopwords, top 50

# %% [markdown]
# # Word Cloud by genre

# %% [markdown]
# En otro dataset, uní los nombres de las bandas que tenía con el género al que representaban, de acuerdo a una lista de wikipedia con bandas para cada género. Principalmente me enfonqué en Heavy, Black, Power y Glam. Luego uní el listado de banda-género, con el listado de banda-letras. El resultado es un subconjunto de bandas que tenían género identificado Y letras disponibles para análisis. <br> El dataframe con letras Y géneros, es _df_en_genre_. <br> El dataframe con letras y 1 género, es _df_en_power df_en_black df_en_heavy df_en_glam_.

# %% [markdown]
# ##### Estandarizar nombres de bandas

# %%
df_en['band_name'] = df_en['band_name'].str.lower()

# %% [markdown]
# ##### Abrir dataset banda género país

# %%
df_genre_country = pd.read_csv('./from_scratch/df_genre_country.csv')
df_genre_country.columns = ['genre', 'rand','band_name', 'country']
df_genre_country['band_name'] = df_genre_country['band_name'].str.lower()

# %% [markdown]
# ##### Merge de letras, géneros y países

# %%
import pandas as pd
result = pd.merge(df_genre_country, df_en, on='band_name')
result.to_csv('./from_scratch/df_en_genre_country_24964lyrics.csv')
result = pd.read_csv('./from_scratch/df_en_genre_country_24964lyrics.csv')
result
# Out:
#        Unnamed: 0        genre            rand  band_name        country  \
# 0               0  Black Metal  0,001425470762  skyforger         Latvia
# 1               1  Black Metal  0,001425470762  skyforger         Latvia
# 2               2  Black Metal  0,001425470762  skyforger         Latvia
# 3               3  Black Metal  0,001425470762  skyforger         Latvia
# 4               4  Black Metal  0,001425470762  skyforger         Latvia
# ...           ...          ...             ...        ...            ...
# 24959       24959  Black Metal    0,9999237571   noctuary  United States
# 24960       24960  Black Metal    0,9999237571   noctuary  United States
# 24961       24961  Black Metal    0,9999237571   noctuary  United States
# 24962       24962  Black Metal    0,9999237571   noctuary  United States
# 24963       24963  Black Metal    0,9999237571   noctuary  United States
#
#        Unnamed: 0.1  Unnamed: 0.1.1              album_name album_year  \
# ...

# %% [markdown]
# ##### Filtrado de datasets por género (3-4)

# %%
df_en_power = result.loc[result['genre'] == 'Power Metal']
df_en_black = result.loc[result['genre'] == 'Black Metal']

# %% [markdown]
# ##### Inglés Power Metal len

# %%
print ("\nCantidad de letras Power Metal")
len(df_en_power)
# Out:
# Cantidad de letras Power Metal
# 13568

# %% [markdown]
# ##### Inglés Power Metal groupby país

# %%
print ("\nCantidad de letras Power Metal, por país, top 5")
country = df_en_power.groupby("country")
country.size().sort_values(ascending=False).head()
# Out:
# Cantidad de letras de Power Metal, por país, top 5
# country
# Germany          3494
# United States    2406
# Sweden           1592
# Finland          1436
# Italy            1002
# dtype: int64

# %% [markdown]
# ##### Inglés Power Metal groupby banda

# %%
print ("\nCantidad de letras Power Metal, por banda, top 5")
country = df_en_power.groupby("band_name")
country.size().sort_values(ascending=False).head()
# Out:
# Cantidad de letras de Power Metal, por banda, top 5
# band_name
# rage            240
# helloween       230
# stratovarius    208
# anvil           200
# gamma ray       197
# dtype: int64

# %% [markdown]
# ##### Inglés Black Metal len

# %%
print ("\nCantidad de letras Black Metal")
len(df_en_black)
# Out:
# Cantidad de letras Black Metal
# 11396

# %% [markdown]
# ##### Inglés Black Metal groupby país

# %%
print ("\nCantidad de letras Black Metal, por país, top 5")
country = df_en_black.groupby("country")
country.size().sort_values(ascending=False).head()
# Out:
# Cantidad de letras Black Metal, por país, top 5
# country
# Norway           2388
# Sweden           1517
# United States     999
# Finland           943
# Germany           755
# dtype: int64

# %% [markdown]
# ##### Inglés Black Metal groupby banda

# %%
print ("\nCantidad de letras Black Metal, por banda, top 5")
country = df_en_black.groupby("band_name")
country.size().sort_values(ascending=False).head(20)
# Out:
# Cantidad de letras Black Metal, por banda, top 5
# band_name
# venom                    219
# king diamond             196
# bathory                  179
# cradle of filth          172
# impaled nazarene         160
# tiamat                   130
# theatres des vampires    129
# destruction              126
# marduk                   123
# behemoth                 120
# samael                   120
# sabbat                   118
# rotting christ           113
# darkthrone               111
# acheron                  104
# mercyful fate            103
# emperor                   95
# sigh                      93
# enthroned                 90
# mayhem                    90
# dtype: int64

# %% [markdown]
# ##### Inglés Black Metal Favoritos

# %%
favoritos = ['darkthrone',
             'mayhem',
             'burzum',
             'dimmu borgir',
             'bathory',
             'satyricon',
             'immortal',
             'gorgoroth',
             'emperor',
             'behemoth',
             'celtic frost',
             'marduk',
             'ulver',
             'enslaved',
             'carpathian forest',
             'dissection',
             'dark funeral',
             'watain',
             'venom',
             'mercyful fate',
             'taake',
             'windir',
             'arcturus',
             'thorns',
             'xasthur',
             'summoning',
             'abruptum',
             'hellhammer',
             'kampfar',
             'limbionic art',
             'abbath',
             'i',
             'necromantia',
             'ancient',
             'ancient rites',
             'demonaz',
             'dodheimsgard',
             'einherjer', 
             'falkenbach',
             'fintroll',
             'hecate enthroned',
             'ihsahn',
             'in the woods...',
             'isengard',
             'king diamond',
             'kampfar',
             'the kovenant',
             'naglfar',
             'nortt',
             'old funeral',
             'opera ix',
             'tsjuder',
             'urgehal'
            ]


favoritos = ['darkthrone',
             'mayhem',
             'burzum',
             'dimmu borgir',
             'bathory',
             'satyricon',
             'immortal',
             'gorgoroth',
             'emperor',
             'arcturus']

# %% [markdown]
# ##### Inglés Black Metal Favoritos len

# %%
df_en_black_favoritos = df_en_black[df_en_black['band_name'].isin(favoritos)]
len(df_en_black_favoritos)
# Out:
# 2598

# %% [markdown]
# ##### Inglés Black Metal Favoritos groupby país

# %%
print ("\nCantidad de letras Black Metal favoritos, por país, top 5")
country = df_en_black_favoritos.groupby("country")
country.size().sort_values(ascending=False).head()
# Out:
# Cantidad de letras Black Metal favoritos, por país, top 5
# country
# Norway            1037
# Sweden             523
# Denmark            300
# United Kingdom     268
# Poland             120
# dtype: int64

# %% [markdown]
# ##### Inglés Black Metal Favoritos groupby banda

# %%
print ("\nCantidad de letras Black Metal favoritos, por banda, top 5")
country = df_en_black_favoritos.groupby("band_name")
country.size().sort_values(ascending=False).head(20)
# Out:
# Cantidad de letras Black Metal favoritos, por banda, top 5
# band_name
# venom                219
# king diamond         196
# bathory              179
# marduk               123
# behemoth             120
# darkthrone           111
# mercyful fate        103
# emperor               95
# mayhem                90
# enslaved              81
# dark funeral          73
# ancient rites         71
# dimmu borgir          69
# immortal              61
# satyricon             61
# celtic frost          61
# carpathian forest     59
# naglfar               57
# summoning             51
# ancient               50
# dtype: int64

# %% [markdown]
# ##### Filtrado de datasets por género + país (5 - 14)

# %%
df_en_power_germany = df_en_power.loc[result['country'] == 'Germany']
df_en_power_usa = df_en_power.loc[result['country'] == 'United States']
df_en_power_sweden = df_en_power.loc[result['country'] == 'Sweden']
df_en_power_finland = df_en_power.loc[result['country'] == 'Finland']
df_en_power_italy = df_en_power.loc[result['country'] == 'Italy']

df_en_black_norway = df_en_black.loc[result['country'] == 'Norway']
df_en_black_sweden = df_en_black.loc[result['country'] == 'Sweden']
df_en_black_usa = df_en_black.loc[result['country'] == 'United States']
df_en_black_finland = df_en_black.loc[result['country'] == 'Finland']
df_en_black_germany = df_en_black.loc[result['country'] == 'Germany']

# %% [markdown]
# # 3 - Inglés, Power (top 50) df_en_power.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_power.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Power Metal'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:13.63
# /n
# Inglés, Power Metal

# %% [markdown]
# # 4 - Inglés, Black (top 50) df_en_black.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:13.15
# Inglés, Black Metal

# %% [markdown]
# # 5 - Inglés, Power, Alemania (top 50) df_en_power_germany.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_power_germany.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Power Metal, Alemania'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:05.84
# Inglés, Power Metal, Alemania

# %% [markdown]
# # 6 - Inglés, Power, Estados Unidos (top 50) df_en_power_usa.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_power_usa.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Power Metal, Estados Unidos'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:05.01
# Inglés, Power Metal, Estados Unidos

# %% [markdown]
# # 7 - Inglés, Power, Suecia (top 50) df_en_power_sweden.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_power_sweden.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Power Metal, Suecia'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:04.14
# Inglés, Power Metal, Suecia

# %% [markdown]
# # 8 - Inglés, Power, Finlandia (top 50) df_en_power_finland.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_power_finland.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Power Metal, Finlandia'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:04.35
# Inglés, Power Metal, Finlandia

# %% [markdown]
# # 9 - Inglés, Power, Italia (top 50) df_en_power_italy.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_power_italy.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Power Metal, Italia'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:03.80
# Inglés, Black Metal, Italia

# %% [markdown]
# # 10 - Inglés, Black, Noruega (top 50) df_en_black_norway.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black_norway.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal, Noruega'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=200,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:08.75
#
#
# Inglés, Black Metal, Noruega

# %% [markdown]
# # 11 - Inglés, Black, Suecia (top 50) df_en_black_sweden.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black_sweden.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal, Suecia'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:04.47
#
#
# Inglés, Black Metal, Suecia

# %% [markdown]
# # 12 - Inglés, Black, Estados Unidos (top 50) df_en_black_usa.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black_usa.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal, Estados Unidos'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:04.10
#
#
# Inglés, Black Metal, Estados Unidos

# %% [markdown]
# # 13 - Inglés, Black, Finlandia (top 50) df_en_black_finland.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black_finland.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal, Finlandia'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:03.76
#
#
# Inglés, Black Metal, Finlandia

# %% [markdown]
# # 14 - Inglés, Black, Alemania (top 50) df_en_black_germany.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black_germany.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal, Alemania'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 10).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:03.96
#
#
# Inglés, Black Metal, Alemania

# %% [markdown]
# # 15 - Inglés, Black, Favoritos (top 50) df_en_black_favoritos.lyric

# %%
#Ingresa df subconjunto 
subconjunto = df_en_black_favoritos.lyric
# Ingresa descripción de la visualización
registro = 'Inglés, Black Metal, favoritos'

##############################################

#Ruta
ruta = './from_scratch/nubes_de_palabras/'
start = time.time()
palabras = '' 
for val in subconjunto: 
    val = str(val) 
    tokens = val.split() 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower()
    palabras += " ".join(tokens)+" "

wordcloud = WordCloud(width = 1600, 
                      height = 1200, 
                      background_color ='black',
                      max_words=50,
                      stopwords = stopwords,
                      collocations=True,
                      relative_scaling=0.8,
                      normalize_plurals=True,
                      min_font_size = 16).generate(palabras)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print('Time elapsed generating wordcloud:')
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
print ('\n')
print (registro)                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

wordcloud.to_file((ruta + registro + '.png'))
# Out:
# Time elapsed generating wordcloud:
# 00:00:05.29
#
#
# Inglés, Black Metal, favoritos
